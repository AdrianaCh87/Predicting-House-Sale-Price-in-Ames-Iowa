# %% [markdown]
# # Predicting the Sale Price of a House in Ames, Iowa

# %% [markdown]
# ### Production Model

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LassoCV 
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score

pd.options.display.max_columns = 100
pd.options.display.max_rows = 200

# %% [markdown]
# ### EDA and Cleaning

# %%
# Load training data from train.csv in datasets folder
file_name_path = './datasets/train.csv'
df = pd.read_csv(file_name_path)

# %%
# Drop Columns not needed in analysis
df.drop(columns=['Id', 'PID', 'Utilities', 'Condition 2','Roof Matl', 'Heating','Low Qual Fin SF', 'Functional', 
                 'Fireplace Qu', 'Paved Drive','Pool Area','Pool QC', 'Mas Vnr Type', 'Mas Vnr Area', 'Bsmt Exposure', 
                 'BsmtFin Type 2','Bsmt Full Bath', 'Bsmt Half Bath', 'Garage Finish','Garage Yr Blt', 
                 'Garage Qual', 'Garage Cond'], inplace=True)

# %%
# Convert the data type in these columns
df['MS SubClass'] = df['MS SubClass'].map(lambda x: str(x))

# %%
# Check if there are any null values in any column
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Lot Frontage       330
# Alley             1911
# Bsmt Qual           55
# Bsmt Cond           55
# BsmtFin Type 1      55
# BsmtFin SF 1         1
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Garage Type        113
# Garage Cars          1
# Garage Area          1
# Fence             1651
# Misc Feature      1986
# dtype: int64

# %%
# Drop Null values in these columns
df.dropna(subset=['Garage Area', 'Garage Cars', 'Total Bsmt SF'], inplace=True)

# %%
# Convert the null values in Lot Frontage to 0
df['Lot Frontage'] = df['Lot Frontage'].map(lambda cell: 0 if pd.isnull(cell) else cell)
# Convert the missing values in Alley to 'no alley'
df['Alley'] = df['Alley'].map(lambda cell: 'no_alley' if pd.isnull(cell) else cell)
# Convert the missing values in Bsmt Qual to 'no bsmt'
df['Bsmt Qual'] = df['Bsmt Qual'].map(lambda cell: 'no_bsmt' if pd.isnull(cell) else cell)
# Convert the missing values in Bsmt Cond to 'no bsmt'
df['Bsmt Cond'] = df['Bsmt Cond'].map(lambda cell: 'no_bsmt' if pd.isnull(cell) else cell)
# Convert the missing values in BsmtFin Type 1 to 'no bsmt'
df['BsmtFin Type 1'] = df['BsmtFin Type 1'].map(lambda cell: 'no_bsmt' if pd.isnull(cell) else cell)
# Convert the missing values in Garage Type to 'no garage'
df['Garage Type'] = df['Garage Type'].map(lambda cell: 'no_garage' if pd.isnull(cell) else cell)
# Convert the null values in Fence to no_fence
df['Fence'] = df['Fence'].map(lambda cell: 'no_fence' if pd.isnull(cell) else cell)
# Convert the null values in Misc Feature to none
df['Misc Feature'] = df['Misc Feature'].map(lambda cell: 'none' if pd.isnull(cell) else cell)

# %%
# Drop columns with multicollinearity
df.drop(columns=['BsmtFin SF 1','BsmtFin SF 2', 'Bsmt Unf SF','1st Flr SF','2nd Flr SF'], inplace=True)

# %%
# Drop outliers
index_to_drop = df[df['Gr Liv Area']>3500].index.values.astype(int)
df.drop(index=index_to_drop, inplace=True)

# %% [markdown]
# ### Preprocessing and Feature Engineering

# %%
# Hot code categorical features
features_to_change = list(df.select_dtypes([np.object]).columns)

# %%
df = pd.get_dummies(df, columns=features_to_change, drop_first=True)

# %%
# Create a function to calculate the y-predictions and residuals for a given model

def check_residual(model, x_test_data, y_test_data):
    
    # Check residuals for baseline model
    if model== 'baseline':
        y_prediction = x_test_data.mean()
        y_predictions = []
        for i in range(0,len(y_test_data)):
            y_predictions.append(y_prediction)
        residuals = y_test_data - y_predictions
        
    # Check residuals for other models
    else:
        y_predictions = model.predict(x_test_data)
        residuals = y_test_data - y_predictions
        
    
    return (y_predictions,residuals)

# %%
# Create a function to calculate R2, MSE, RMSE

def evaluate_model(model, X, y):
    
    # Evalute baseline model
    if model == 'baseline':
        # Convert y_baseline to an array to calculate baseline metrics
        y_baseline = []
        for i in range(0,len(y)):
            y_baseline.append(X)
            
        print(f'Baseline: Avg Price = {X}')
        print(f'R2 Score: {r2_score(y, y_baseline)}')
        print(f'MSE: {mean_squared_error(y, y_baseline)}')
        print(f'RMSE: {np.sqrt(mean_squared_error(y, y_baseline))}')
        
    else:
    # Evaluate other models
        print(f'R2 Score: {r2_score(y, model.predict(X))}')
        print(f'MSE: {mean_squared_error(y, model.predict(X))}')
        print(f'RMSE: {np.sqrt(mean_squared_error(y, model.predict(X)))}')

# %%
# Set X and y
X_lasso = df.drop(columns=['SalePrice'], axis=1)
y_lasso = df['SalePrice']

# %%
X_lasso.drop(columns=['Misc Feature_TenC', 'Electrical_Mix', 'Heating QC_Po', 
                'Bsmt Cond_Fa', 'Garage Type_no_garage', 'Bsmt Cond_Po', 'Exterior 1st_CBlock', 
                'BsmtFin Type 1_no_bsmt', 'Exterior 1st_ImStucc', 'Neighborhood_Landmrk', 
                'Exterior 1st_Stone', 'Bsmt Qual_no_bsmt', 'Exterior 2nd_Stone', 'Misc Feature_none', 
                'MS Zoning_C (all)', 'Bsmt Cond_no_bsmt', 'Neighborhood_GrnHill', 'Alley_no_alley',
                      'Fence_no_fence'], inplace=True)

# %%
# Perform a split of x and y
XL_train, XL_test, yl_train, yl_test = train_test_split(X_lasso, y_lasso, random_state=42)

# Scale and fit 
ss_lasso = StandardScaler()
XLs_train = ss_lasso.fit_transform(XL_train)
XLs_test = ss_lasso.transform(XL_test)

# %% [markdown]
# ### Modeling

# %%
# Set up a list of Lasso alphas to check.
l_alphas = np.logspace(-3, 0, 100)

# Cross-validate over list of Lasso alphas.
lasso_cv = LassoCV(alphas=l_alphas, cv=5, max_iter=50000)

# Fit model using best alpha
lasso_cv.fit(XLs_train, yl_train);

lasso_cv.score(XLs_train, yl_train), lasso_cv.score(XLs_test, yl_test)
# Out:
# (0.9286577521862895, 0.9059810796058696)

# %%
cross_val_score(lasso_cv, XLs_train, yl_train).mean()
# Out:
# 0.8919610872942642

# %% [markdown]
# ### Model Coefficients

# %%
pd.DataFrame({
    'Feature': X_lasso.columns,
    'coef_value': lasso_cv.coef_
}).set_index('Feature').sort_values('coef_value', ascending=False)
# Out:
#                         coef_value
# Feature
# Gr Liv Area           25001.751692
# Total Bsmt SF         13018.862891
# MS SubClass_20        12435.041165
# Year Built            11347.105597
# Overall Qual           9772.625652
# MS SubClass_60         8098.109039
# MS SubClass_50         7677.490134
# Overall Cond           7063.687348
# Lot Area               6775.763518
# MS SubClass_30         6689.415472
# Garage Area            5016.964426
# MS SubClass_70         4761.052550
# Sale Type_New          4619.693992
# Land Contour_HLS       4028.506867
# BsmtFin Type 1_GLQ     3678.940956
# Screen Porch           3547.881844
# House Style_2Story     3469.121884
# MS Zoning_RL           3400.948900
# MS Zoning_RM           3332.957251
# House Style_SLvl       3105.785521
# MS Zoning_FV           3054.339133
# Exterior 1st_VinylSd   3050.318875
# Exterior 2nd_HdBoard   2952.119615
# Exterior 1st_MetalSd   2794.978312
# Wood Deck SF           2680.296851
# Condition 1_Norm       2650.636205
# Neighborhood_StoneBr   2626.411892
# Exterior 1st_BrkFace   2578.209742
# MS SubClass_80         2577.904613
# Foundation_PConc       2510.556507
# MS SubClass_90         2444.928219
# Fireplaces             2209.923297
# Condition 1_PosN       2184.920214
# MS SubClass_85         1992.424050
# House Style_SFoyer     1916.474877
# MS Zoning_RH           1896.305577
# Sale Type_WD           1808.989827
# Sale Type_Oth          1790.457186
# Year Remod/Add         1684.351054
# Land Contour_Lvl       1643.794262
# Sale Type_Con          1608.680789
# House Style_2.5Unf     1554.751517
# Bldg Type_Duplex       1540.375731
# MS SubClass_190        1532.630913
# Exterior 2nd_CmentBd   1453.484802
# Lot Config_CulDSac     1440.071324
# Bldg Type_2fmCon       1426.122024
# Exterior 2nd_Plywood   1329.635404
# Half Bath              1316.422154
# Condition 1_PosA       1218.608388
# Exterior 2nd_Wd Shng   1206.834856
# Foundation_CBlock      1200.751306
# House Style_1.5Unf     1164.347546
# Exterior 2nd_Wd Sdng   1164.182789
# MS SubClass_75         1161.506924
# Bsmt Cond_TA           1105.559333
# Open Porch SF          1041.110380
# House Style_1Story     1028.600930
# Exterior 2nd_AsphShn   1012.062505
# Condition 1_Feedr       993.472512
# Neighborhood_NoRidge    993.340068
# MS SubClass_45          987.481732
# MS SubClass_40          976.408336
# Sale Type_ConLD         962.010486
# Exterior 1st_CemntBd    867.452340
# Lot Frontage            845.107423
# Exterior 2nd_Brk Cmn    778.403691
# Misc Feature_Othr       765.053593
# Full Bath               713.481132
# Garage Type_BuiltIn     672.536735
# Land Contour_Low        657.897541
# Foundation_Wood         649.255554
# Land Slope_Mod          643.268477
# Exterior 2nd_BrkFace    642.860543
# Condition 1_RRAn        582.103988
# Sale Type_CWD           580.176328
# Sale Type_ConLw         563.661958
# Exterior 2nd_Stucco     530.183027
# Neighborhood_NridgHt    507.572646
# Fence_MnPrv             499.094468
# Misc Feature_Shed       468.354011
# Sale Type_ConLI         462.942267
# Exterior 2nd_CBlock     455.857346
# Enclosed Porch          446.364431
# Bsmt Cond_Gd            396.416752
# Electrical_FuseF        351.289974
# Bldg Type_Twnhs         328.420389
# Electrical_FuseP        304.227807
# Exterior 1st_Wd Sdng    280.299161
# Lot Shape_Reg           237.697668
# Land Slope_Sev          222.186529
# Street_Pave             219.717999
# Foundation_Slab         211.577692
# Lot Shape_IR2           193.859185
# Garage Type_CarPort     185.095187
# Lot Config_FR3          178.180550
# Exterior 2nd_MetalSd    171.066218
# Garage Cars             166.593852
# Exterior 2nd_ImStucc    160.430642
# Bldg Type_TwnhsE        151.705058
# BsmtFin Type 1_BLQ      133.638699
# Neighborhood_Greens     127.139611
# Exterior 1st_Plywood     81.689777
# Exterior 1st_WdShing     80.801817
# Lot Config_Inside        57.057682
# Exterior 2nd_VinylSd     18.875686
# Mo Sold                   6.668835
# Exterior 1st_Stucco       5.630501
# Bsmt Qual_Po              0.000000
# Exterior 1st_AsphShn      0.000000
# TotRms AbvGrd           -16.414388
# Roof Style_Hip          -56.345280
# Heating QC_Gd           -65.895950
# MS SubClass_180         -95.444287
# MS Zoning_I (all)      -101.058354
# Garage Type_Basment    -112.720505
# MS SubClass_160        -131.312127
# 3Ssn Porch             -132.240649
# Heating QC_Fa          -173.672690
# Misc Val               -228.013137
# Electrical_SBrkr       -230.253154
# Roof Style_Shed        -308.342858
# Fence_GdWo             -350.076826
# Foundation_Stone       -363.895418
# Yr Sold                -369.264608
# Condition 1_RRNe       -414.667216
# Fence_MnWw             -468.515802
# Alley_Pave             -474.304943
# Roof Style_Gambrel     -543.572566
# Condition 1_RRNn       -640.131866
# Condition 1_RRAe       -671.235296
# BsmtFin Type 1_LwQ     -682.376507
# Lot Config_FR2         -693.755838
# MS SubClass_150        -816.377820
# House Style_2.5Fin     -816.609562
# Neighborhood_BrDale    -862.511814
# Neighborhood_NPkVill   -897.178684
# Lot Shape_IR3          -996.910459
# Exterior 1st_BrkComm  -1017.252630
# Exter Cond_Po         -1038.042491
# BsmtFin Type 1_Rec    -1043.532900
# Heating QC_TA         -1072.624945
# Neighborhood_Blueste  -1076.780840
# Garage Type_Detchd    -1176.384317
# Exter Cond_Fa         -1209.348695
# Central Air_Y         -1270.539532
# Roof Style_Gable      -1278.694748
# Neighborhood_Veenker  -1820.431948
# Bsmt Qual_Fa          -1850.625498
# Roof Style_Mansard    -1882.938217
# Garage Type_Attchd    -1886.053969
# Exterior 1st_HdBoard  -2218.928114
# Exter Cond_Gd         -2254.661935
# Neighborhood_ClearCr  -2349.414004
# Neighborhood_Crawfor  -2448.305429
# Exter Cond_TA         -2545.809351
# Neighborhood_MeadowV  -2687.630038
# Neighborhood_Timber   -2731.216856
# Neighborhood_SWISU    -3157.897034
# Kitchen AbvGr         -3242.536295
# Neighborhood_BrkSide  -3252.485058
# Kitchen Qual_Fa       -3296.822438
# BsmtFin Type 1_Unf    -3692.800284
# Neighborhood_Somerst  -3932.943210
# Exter Qual_Fa         -4050.808958
# Bedroom AbvGr         -4265.400584
# Neighborhood_IDOTRR   -4795.417948
# Neighborhood_SawyerW  -5252.373173
# Neighborhood_Sawyer   -5352.314302
# Neighborhood_Mitchel  -5596.158723
# Neighborhood_Gilbert  -6065.186718
# Neighborhood_NWAmes   -6348.780847
# Neighborhood_CollgCr  -6521.589431
# Neighborhood_Edwards  -7846.896605
# Neighborhood_OldTown  -8490.531680
# Bsmt Qual_TA          -8664.388990
# Kitchen Qual_Gd       -9347.352519
# Neighborhood_NAmes   -10032.189526
# Bsmt Qual_Gd         -10137.167673
# Kitchen Qual_TA      -10439.399343
# Exter Qual_Gd        -12639.593703
# Exter Qual_TA        -14029.850713

# %% [markdown]
# ### Model Metrics

# %%
evaluate_model(lasso_cv, XLs_test, yl_test)
# Out:
# R2 Score: 0.9059810796058696
# MSE: 609178044.6667025
# RMSE: 24681.53246187729

# %%
yl_predictions, yl_residuals = check_residual(lasso_cv, XLs_test, yl_test)

# %% [markdown]
# Model Insights
#
# Residual plots indicate that the model is not performing as well for outliers. Overall, the performance of the model is satisfactory. The model found strong predictors for house sale price. Model is low bias and low variance.
#
# Recommend to validate the model over time to confirm its accuracy.
#
# Coefficients in model can be interpreted as
